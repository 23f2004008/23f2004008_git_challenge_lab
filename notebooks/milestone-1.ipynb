# %%
# Configure Git user for commits
subprocess.run(['git', 'config', 'user.email', '23f2004008@student.edu'], cwd=os.getcwd())
subprocess.run(['git', 'config', 'user.name', '23f2004008'], cwd=os.getcwd())

# Create .gitignore
with open('.gitignore', 'w') as f:
    f.write('__pycache__/\n*.pyc\n.DS_Store\n*.egg-info/\n.ipynb_checkpoints/\n')

# Stage and commit initial files
subprocess.run(['git', 'add', '.'], cwd=os.getcwd())
result = subprocess.run(['git', 'commit', '-m', 'Initial commit: Project structure setup'], cwd=os.getcwd(), capture_output=True, text=True)
print(result.stdout)
print(result.stderr)

# %% [markdown]
# ## Section 3: Add and Commit Initial Files
#
# Create initial files like requirements.txt and README.md, then add and commit them using Git.

# %%
# Create project directories
directories = ['notebooks', 'src', 'reports', 'models']

for directory in directories:
    os.makedirs(directory, exist_ok=True)
    print(f"Created directory: {directory}")

print("\nDirectory structure created successfully!")

# %% [markdown]
# ## Section 2: Create Project Directory Structure
#
# Use Python's os module to create the specified directories: notebooks, src, reports, and models.

# %%
import os
import subprocess

# Initialize Git repository
result = subprocess.run(['git', 'init'], cwd=os.getcwd(), capture_output=True, text=True)
print(result.stdout)
print(result.stderr)

# %% [markdown]
# ## Section 1: Initialize Git Repository
#
# Use Git commands to initialize a new repository in the project directory.

# %% [markdown]
# # Milestone 1: Initialize Git Repository and Project Structure
#
# This notebook demonstrates the initial setup of the Git Challenge Lab project, including repository initialization and directory structure creation.
